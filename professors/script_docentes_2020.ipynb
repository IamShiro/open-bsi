# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3ae3ade3-fe0b-4d5e-9050-74348110a01f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ae3ade3-fe0b-4d5e-9050-74348110a01f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving docentes_2020_1.csv to docentes_2020_1.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('docentes_2020_1.csv', na_filter=False)
df.columns = ['name', 'email', 'department', 'title', 'research', 'lattes', 'int_bkg', 'mkt_bkg']
df
# Out:
#                                     name  ...                                            mkt_bkg
# 0                   Ana Cristina Roiller  ...  Sócio Fundador na Empresa SWQuality Consultori...
# 1     Antônio José Ferreira Gomes Junior  ...
# 2       Brigitte Renata Bezerra Oliveira  ...
# 3   Catarina Rosa e Silva de Albuquerque  ...
# 4                         Cícero Garrozi  ...  Sócio-fundador da MachLeV smart solutions (gra...
# 5                 Claúdio Tadeu Cristino  ...
# 6                      Cleviton Monteiro  ...  Sócio-fundador da FAST Tecnologia, Mentor da M...
# 7                        Elizabeth Tscha  ...  Consultoria e pesquisas para empresas de forma...
# 8                          Gabriel Alves  ...  Trabalhou em empresas como a Pitang e CESAR; M...
# 9               Glauco Estácio Gonçalves  ...    Participou em projetos de P&D&I com Ericsson AB
# 10                       Guilherme Vilar  ...
# ...

# %%
with open('docentes_2020_1.json', 'w', encoding='utf-8') as file:
    df.to_json(file, force_ascii=False, orient='records')
